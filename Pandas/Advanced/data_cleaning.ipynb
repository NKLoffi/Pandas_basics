# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/nikhilaji/Documents/Pandas_basics/Pandas/Data Jobs.csv')

# %%
# Data Clean up

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.loc[:10, 'salary_year_avg': 'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled["salary_hour_avg"].fillna(median_salary_hour)

# %%
df_filled.loc[:10, 'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %% [markdown]
# # Dropping Duplicate rows

# %%
df_unique = df_filled

df_unique =  df_unique.drop_duplicates()

print('Length of the orginal df:                ', len(df_filled))
print('Length of drop duplicates df:            ', len(df_unique))
print('Rows Dropped:                            ', len(df_filled)-len(df_unique))
# Out:
# Length of the orginal df:                 785741
# Length of drop duplicates df:             785640
# Rows Dropped:                             101

# %%
df_unique = df_unique.drop_duplicates(subset= ['job_title', 'company_name'])

print('Length of the orginal df:                ', len(df_filled))
print('Length of drop duplicates df:            ', len(df_unique))
print('Rows Dropped:                            ', len(df_filled)-len(df_unique))
# Out:
# Length of the orginal df:                 785741
# Length of drop duplicates df:             508042
# Rows Dropped:                             277699

# %%
df.sample(10) # randomply select 10 rows from the data frame
# Out:
#               job_title_short  \
# 634324           Data Analyst
# 458483           Data Analyst
# 573996           Data Analyst
# 170685           Data Analyst
# 499695  Senior Data Scientist
# 222774  Senior Data Scientist
# 445659      Software Engineer
# 247171          Data Engineer
# 600624           Data Analyst
# 370764          Data Engineer
#
#                                                 job_title  \
# 634324                               Medical Data Analyst
# 458483                              Business Data Analyst
# 573996                         middle/senior data analyst
# 170685                                 Data Analyst｜資料分析師
# 499695  Senior Consultant Cloud Analytics & Data Scien...
# 222774                          Senior Data Product Owner
# 445659                       Software Engineering Manager
# 247171                                      Data Engineer
# 600624                    Language Data Analyst - Finnish
# 370764                                      Data Engineer
#
#                      job_location                job_via  \
# 634324                Chelsea, MA              via BeBee
# 458483                   Anywhere  via LinkedIn Bulgaria
# 573996  Mexico City, CDMX, Mexico       via BeBee México
# 170685                     Taiwan          via Meet.jobs
# 499695           Cologne, Germany           via LinkedIn
# 222774                  Singapore             via Indeed
# 445659             Nairobi, Kenya        via BeBee Kenya
# 247171             Puebla, Mexico       via BeBee México
# 600624              Cork, Ireland           via LinkedIn
# 370764                  Singapore        via Recruit.net
#
#               job_schedule_type  job_work_from_home          search_location  \
# 634324  Full-time and Part-time               False  New York, United States
# 458483                Full-time                True                 Bulgaria
# 573996                Full-time               False                   Mexico
# 170685                      NaN               False                   Taiwan
# 499695  Full-time and Part-time               False                  Germany
# 222774                Full-time               False                Singapore
# 445659                Full-time               False                    Kenya
# 247171                Full-time               False                   Mexico
# 600624                Full-time               False                  Ireland
# 370764                Full-time               False                Singapore
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 634324 2023-11-23 12:00:41                  False                 False
# 458483 2023-07-25 14:40:44                  False                 False
# 573996 2023-04-08 09:31:21                  False                 False
# 170685 2023-02-09 00:01:35                   True                 False
# 499695 2023-09-22 11:35:46                  False                 False
# 222774 2023-10-07 22:17:02                   True                 False
# 445659 2023-06-28 17:04:26                  False                 False
# 247171 2023-06-13 07:13:59                   True                 False
# 600624 2023-01-06 09:44:35                   True                 False
# 370764 2023-06-15 23:41:29                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 634324  United States         NaN         115000.0            45.98
# 458483       Bulgaria         NaN         115000.0            45.98
# 573996         Mexico         NaN         115000.0            45.98
# 170685         Taiwan         NaN         115000.0            45.98
# 499695        Germany         NaN         115000.0            45.98
# 222774      Singapore         NaN         115000.0            45.98
# 445659          Kenya         NaN         115000.0            45.98
# 247171         Mexico         NaN         115000.0            45.98
# 600624        Ireland         NaN         115000.0            45.98
# 370764      Singapore         NaN         115000.0            45.98
#
#                             company_name  \
# 634324                              MASS
# 458483  Novi Global Recruitment Bulgaria
# 573996              Svitla Systems, Inc.
# 170685               JKOPAY 街口電子支付股份有限公司
# 499695                          Deloitte
# 222774           LittleLives Inc Pte Ltd
# 445659                         Canonical
# 247171            LION SYSTEMS SOLUTIONS
# 600624               TELUS International
# 370764      Eps Computer Systems Pte Ltd
#
#                                                job_skills  \
# 634324      ['sql', 'python', 'excel', 'word', 'tableau']
# 458483                        ['sql', 'excel', 'tableau']
# 573996  ['sql', 'python', 'r', 'julia', 'ruby', 'ruby'...
# 170685                                            ['sql']
# 499695  ['python', 'r', 'scala', 'sas', 'sas', 'azure'...
# 222774                                            ['sql']
# 445659                                  ['sql', 'ubuntu']
# 247171                 ['sql', 'sql server', 'snowflake']
# 600624                                          ['react']
# 370764  ['sql', 'azure', 'databricks', 'kafka', 'word'...
#
#                                           job_type_skills
# 634324  {'analyst_tools': ['excel', 'word', 'tableau']...
# 458483  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 573996  {'analyst_tools': ['looker', 'excel'], 'cloud'...
# 170685                           {'programming': ['sql']}
# 499695  {'analyst_tools': ['sas'], 'cloud': ['azure', ...
# 222774                           {'programming': ['sql']}
# 445659         {'os': ['ubuntu'], 'programming': ['sql']}
# 247171  {'cloud': ['snowflake'], 'databases': ['sql se...
# 600624                           {'libraries': ['react']}
# 370764  {'analyst_tools': ['word'], 'cloud': ['azure',...

# %%
df.sample(10, random_state= 42) # returns 10 random rows but dosen't change when rerunning. SAME 10 ROWS
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901         NaN         115000.0            45.98           ManpowerGroup
# 406337         NaN         115000.0            45.98                 Harnham
# 659951         NaN         115000.0            45.98             Morgan King
# 541593         NaN         115000.0            45.98                 Konnekt
# 425158         NaN         115000.0            45.98  Independent Recruiters
# 183426         NaN         115000.0            45.98    FLEXOSENSE PTE. LTD.
# 287790         NaN         115000.0            45.98      Iris Software Inc.
# 541983         NaN         115000.0            45.98                    SAIC
# 416896         NaN         115000.0            45.98             KPMG France
# 780907         NaN         115000.0            45.98        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                                NaN
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                                NaN
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                                NaN
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                                NaN
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %% [markdown]
# # Copy()
#
# ##### The line df_altered = df.copy() creates a deep copy of the DataFrame df and assigns it to a new variable named df_altered.

# %%
df_altered = df.copy()

# %%
print('ID of df:  ', id(df))
print('ID of df_altered: ', id(df_altered))
print('Are the two dataframes same: ', id(df) == id(df_altered))
# Out:
# ID of df:   5356032496
# ID of df_altered:  6066463296
# Are the two dataframes same:  False
