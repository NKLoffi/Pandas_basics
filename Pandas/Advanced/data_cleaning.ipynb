# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/nikhilaji/Documents/Pandas_basics/Pandas/Data Jobs.csv')

# %%
# Data Clean up

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.loc[:10, 'salary_year_avg': 'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled["salary_hour_avg"].fillna(median_salary_hour)

# %%
df_filled.loc[:10, 'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %% [markdown]
# # Dropping Duplicate rows

# %%
df_unique = df_filled

df_unique =  df_unique.drop_duplicates()

print('Length of the orginal df:                ', len(df_filled))
print('Length of drop duplicates df:            ', len(df_unique))
print('Rows Dropped:                            ', len(df_filled)-len(df_unique))
# Out:
# Length of the orginal df:                 785741
# Length of drop duplicates df:             785640
# Rows Dropped:                             101

# %%
df_unique = df_unique.drop_duplicates(subset= ['job_title', 'company_name'])

print('Length of the orginal df:                ', len(df_filled))
print('Length of drop duplicates df:            ', len(df_unique))
print('Rows Dropped:                            ', len(df_filled)-len(df_unique))
# Out:
# Length of the orginal df:                 785741
# Length of drop duplicates df:             508042
# Rows Dropped:                             277699

# %%
df.sample(10) # randomply select 10 rows from the data frame
# Out:
#               job_title_short  \
# 498353          Data Engineer
# 687093    Senior Data Analyst
# 73198           Data Engineer
# 192786  Senior Data Scientist
# 235903         Data Scientist
# 477733          Data Engineer
# 203710           Data Analyst
# 468246   Senior Data Engineer
# 317152   Senior Data Engineer
# 40194          Data Scientist
#
#                                                job_title  \
# 498353             Data Engineer (6200 USD/Mes) [Remote]
# 687093                   Senior Data Analyst - Stockholm
# 73198                 Lead Data Engineer (Python, Spark)
# 192786                             Senior Data Scientist
# 235903        Draslovka - Data Scientist - Prague Office
# 477733                       Tech Lead Data Engineer F/H
# 203710    Business/Data Analyst Manager- AVP -C12-Hybrid
# 468246                    Senior Data Engineer/ SQL SSIS
# 317152                              Senior Data Engineer
# ...

# %%
df.sample(10, random_state= 42) # returns 10 random rows but dosen't change when rerunning. SAME 10 ROWS
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %% [markdown]
# # Copy()
#
# ##### The line df_altered = df.copy() creates a deep copy of the DataFrame df and assigns it to a new variable named df_altered.

# %%
df_altered = df.copy()

# %%
print('ID of df:  ', id(df))
print('ID of df_altered: ', id(df_altered))
print('Are the two dataframes same: ', id(df) == id(df_altered))
# Out:
# ID of df:   13095296544
# ID of df_altered:  13094691920
# Are the two dataframes same:  False

# %%
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan              115000.0             NaN      115000.0
# Albania                  115000.0        115000.0      115000.0
# Algeria                  115000.0        115000.0      115000.0
# Angola                   115000.0             NaN      115000.0
# Argentina                115000.0        115000.0      115000.0
# ...                           ...             ...           ...
# Venezuela                115000.0        115000.0      115000.0
# Vietnam                  115000.0        115000.0      115000.0
# Yemen                    115000.0             NaN      115000.0
# Zambia                   115000.0        115000.0      115000.0
# Zimbabwe                 115000.0        115000.0      115000.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN        115000.0                        NaN
# ...

# %%
# Out:
# <Axes: xlabel='job_country'>
